# %%
import pandas as pd

# %%
df_futbol = pd.read_csv('players_20_new.csv')
df_futbol.set_index('short_name', inplace=True)
df_futbol
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# ### 1 sample()

# %%
# Extraer 10 elementos aleatorios de la columna "nationality"
df_futbol['nationality'].sample(n=10, random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
# Extraer el 20% de muestra aleatoria del DF
df_futbol.sample(frac=0.2, random_state=999)
# Out:
#                                 long_name  age         dob  height_cm  \
# short_name
# A. Feick                       Arne Feick   31  1988-04-01        179
# B. Manosalva             Brayan Manosalva   21  1997-07-14        185
# Edigar Junio   Edigar Junio Teixeira Lima   28  1991-05-06        174
# G. Muzinga           Glody Ngonda Muzinga   24  1994-12-31        175
# F. Al Birekan            Firas Al Birekan   19  2000-05-14        181
# ...                                   ...  ...         ...        ...
# M. Kobylański           Martin Kobylański   25  1994-03-08        178
# N. Contini                 Nikita Contini   23  1996-05-21        190
# L. Kalinić                  Lovre Kalinić   29  1990-04-03        201
# S. Ntshangase        Siphelele Ntshangase   26  1993-05-11        172
# I. Vujica                     Ivan Vujica   22  1997-04-20        180
#
#                weight_kg   nationality                    club
# short_name
# ...

# %%
# Imcrementar la muestra -> frac>1 (obs: el parametro replace tiene que er Ture cuando el parametro frac>1)
df_futbol.sample(frac=2, replace=True, random_state=66)
# Out:
#                                         long_name  age         dob  height_cm  \
# short_name
# Víctor                         Víctor García Raja   22  1997-01-01        180
# J. Clarke-Harris             Jonson Clarke-Harris   24  1994-07-21        183
# K. Gunnarshaug             Kristoffer Gunnarshaug   20  1999-05-11        180
# A. Rocha                               Aldo Rocha   26  1992-11-06        167
# Flávio                      Flávio da Silva Ramos   25  1994-05-12        191
# ...                                           ...  ...         ...        ...
# Q. Lecoeuche                    Quentin Lecoeuche   25  1994-02-04        172
# Andreas Pereira   Andreas Hugo Hoelgebaum Pereira   23  1996-01-01        178
# B. Lennon                           Brooks Lennon   21  1997-09-22        177
# O. Diagne                        Ousseynou Diagne   20  1999-06-05        190
# Joaquim Adão                         Joaquim Adão   26  1992-07-14        176
#
# ...
